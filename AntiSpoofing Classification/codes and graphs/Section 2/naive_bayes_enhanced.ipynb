# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
from google.colab import drive
drive.mount('/content/drive')
dataset=pd.read_csv("/content/drive/MyDrive/dataset2.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
dataset = dataset.replace(float('-inf'), 0)


#dataset['magnitude_spectrum'] = dataset['magnitude_spectrum'].replace('-inf', dataset['magnitude_spectrum'].min())
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)
# Out:
# Mounted at /content/drive

# %%
print (dataset)
# Out:
#       brightness  contrast     pattern  color_difference  edge_density  \
# 0      99.702134  0.416570  175.309872         24.562875     88.403188
# 1      97.335692  0.623163  185.284147         57.123306     45.465668
# 2      92.069242  0.619442  177.027386         62.602832     72.193555
# 3     101.765685  0.612922  162.092529         63.141719     79.343781
# 4      89.973461  0.622225  162.502445         61.500500     31.618202
# ...          ...       ...         ...               ...           ...
# 3412  110.619807  0.399236  200.791773          3.726273     36.949285
# 3413  134.773247  0.375260  224.631836         22.195187     21.403370
# 3414  115.248466  0.412123  217.522831          4.510632     40.676422
# 3415  115.386924  0.413096  187.003233         19.096985     44.688034
# 3416  112.719294  0.354879  214.505047          4.233398     29.153035
#
#       fractional_dimension           b           g           r        var_b  \
# 0             5.364788e-01   59.150190  108.062914   98.769631  1302.127016
# 1             1.036944e+00   85.665575  103.026631   90.608499  6829.390011
# 2             9.941398e-01   88.460397   93.578682   90.488929  3779.954141
# 3             6.199279e-01   77.527173  108.002131   98.768269  3552.510062
# 4             9.604516e-01   58.748621   96.887482   88.296356  2729.511597
# ...                    ...         ...         ...         ...          ...
# 3412          1.116414e-15  114.921968  112.496357  105.301193  1388.469244
# 3413          8.982784e-01  176.742966  137.606148  113.215843  2988.669087
# 3414          1.428571e-01  134.376606  124.196892   90.406948  1325.233393
# 3415          6.362820e-01  123.231947  117.173024  108.925603  2570.799947
# 3416          1.785714e-01  106.117772  111.112735  118.406194  2120.511037
#
#             var_g        var_r  magnitude_spectrum      hist_b      hist_g  \
# 0     1896.216524  1806.431405        3.439379e+08    960000.0    960000.0
# 1     3699.341809  3042.371612        3.071700e+08    956400.0    956400.0
# 2     3297.786784  3115.491785        9.590365e+07    307200.0    307200.0
# 3     4193.829135  3702.756707        1.671020e+08    480000.0    480000.0
# 4     3687.852855  2955.587080        5.043666e+09  13381632.0  13381632.0
# ...           ...          ...                 ...         ...         ...
# 3412  1933.335585  3039.505995        1.621558e+08    589824.0    589824.0
# 3413  2496.943330  2865.725361        0.000000e+00    262144.0    262144.0
# 3414  1672.401785  5750.892998        8.427041e+07    262144.0    262144.0
# 3415  2214.142175  2509.146231        1.701464e+08    589824.0    589824.0
# 3416  1648.365102  1559.264485        0.000000e+00    589824.0    589824.0
#
#           hist_r
# 0       960000.0
# 1       956400.0
# 2       307200.0
# 3       480000.0
# 4     13381632.0
# ...          ...
# 3412    589824.0
# 3413    262144.0
# 3414    262144.0
# 3415    589824.0
# 3416    589824.0
#
# [3417 rows x 16 columns]

# %%
from sklearn.naive_bayes import GaussianNB
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
nb = GaussianNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.34457049720026267
# Accuracy:  0.2621832358674464
# F1 Score:  0.20754962331666224
# [[ 43 121   2   0   0   0]
#  [ 18 145   2   0   0   0]
#  [ 17 137   4   0   0   1]
#  [ 52  61   1  36   5  14]
#  [ 37  97   1  27   4  28]
#  [ 30  86   0  16   4  37]]

# %%
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
nb = BernoulliNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.17066937029760462
# Accuracy:  0.31773879142300193
# F1 Score:  0.2086920907868574
# [[  0   0  71  92   0   3]
#  [  0   0 126  30   0   9]
#  [  0   0 121  35   0   3]
#  [  0   0   8 136   0  25]
#  [  0   0  30 119   0  45]
#  [  0   0  18  86   0  69]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"

# %%
#for index, row in dataset.iterrows():
#    row['fractional_dimension']=row['fractional_dimension']*10

X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)

# %%
nb = GaussianNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.785941694272949
# Accuracy:  0.6471734892787524
# F1 Score:  0.6070096783044077
# [[486   4]
#  [358 178]]

# %%
nb = BernoulliNB(alpha=1.0, fit_prior=False)
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.7906747008154442
# Accuracy:  0.7777777777777778
# F1 Score:  0.773709315375982
# [[318 172]
#  [ 56 480]]
