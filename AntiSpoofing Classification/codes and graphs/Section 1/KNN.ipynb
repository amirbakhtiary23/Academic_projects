# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
from google.colab import drive
drive.mount('/content/drive')
dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)

# %% [markdown]
# this section fit the model using 3 nearest neighbor and 6 classes

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
k = 3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.4239134999253386
# Accuracy:  0.41130604288499023
# F1 Score:  0.406803479133997
# [[95 10  3 48  9  1]
#  [18 77 32 13 13 12]
#  [ 7 43 63  2 12 32]
#  [55 12  4 84 11  3]
#  [29 67 19  8 50 21]
#  [ 7 44 45  8 16 53]]

# %% [markdown]
# this section fit the model using 9 nearest neighbor and 6 classes

# %%
k = 9
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.445217579835751
# Accuracy:  0.43762183235867447
# F1 Score:  0.4352871837316821
# [[89 10  4 52 11  0]
#  [12 84 31  9 18 11]
#  [ 5 36 63  3 16 36]
#  [54  8  2 89 12  4]
#  [14 68 21 13 58 20]
#  [ 7 33 46  5 16 66]]

# %% [markdown]
# here we convert our dataset to two classes , real and fake, and hence we don't need the channel means, we drop them as well

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"
dataset=dataset.drop("g",axis=1)
dataset=dataset.drop("r",axis=1)
dataset=dataset.drop("b",axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)

# %% [markdown]
# binary KNN with the k of 12

# %%
k = 12
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.6223692371545557
# Accuracy:  0.6120857699805068
# F1 Score:  0.6089394745450805
# [[350 140]
#  [258 278]]

# %% [markdown]
# from here we use our enhanced dataset which has 3 additional features. these additiona features are the variance of colors in each channel

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
from google.colab import drive
drive.mount('/content/drive')
dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)
# Out:
# Mounted at /content/drive

# %% [markdown]
# we test 3NN using new dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
k = 3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.32231521168401045
# Accuracy:  0.29239766081871343
# F1 Score:  0.2947917720513106
# [[72 32 13 38  8  3]
#  [40 50 29 17 18 11]
#  [24 53 33  6 14 29]
#  [51 31 11 58 13  5]
#  [36 63 21 15 43 16]
#  [21 53 33  6 16 44]]

# %%
k = 9
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.3184294375663737
# Accuracy:  0.30701754385964913
# F1 Score:  0.3091447279706195
# [[64 34 15 41  8  4]
#  [25 51 28 15 33 13]
#  [15 42 39  7 18 38]
#  [45 21 18 62 18  5]
#  [23 54 28 17 53 19]
#  [10 32 44 14 27 46]]

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"

# %%
k = 12
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.3358268297841947
# Accuracy:  0.3206627680311891
# F1 Score:  0.32363422942062453
# [[64 33 17 41  6  5]
#  [21 56 30 14 32 12]
#  [ 9 41 41 12 16 40]
#  [32 25 20 69 18  5]
#  [23 65 28 11 50 17]
#  [ 7 32 43 19 23 49]]

# %%
dataset=dataset.drop("g",axis=1)
dataset=dataset.drop("r",axis=1)
dataset=dataset.drop("b",axis=1)
dataset=dataset.drop("var_g",axis=1)
dataset=dataset.drop("var_r",axis=1)
dataset=dataset.drop("var_b",axis=1)

# %% [markdown]
# testing for the second time without variances

# %%
k = 12
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X_train, y_train['label'].ravel())
y_pred = knn.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.6223692371545557
# Accuracy:  0.6120857699805068
# F1 Score:  0.6089394745450805
# [[350 140]
#  [258 278]]
