# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.4, random_state=42)

# %%
tree = DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_leaf=2,
#                        min_samples_split=5)

# %%
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.3718514950699421
# Accuracy:  0.3694220921726408
# F1 Score:  0.368119725058922
# [[117  13   8  74  15   3]
#  [ 31  75  43   9  45  23]
#  [  9  61  72   6  26  35]
#  [ 74  13  10 114  19   7]
#  [ 17  76  35  18  69  32]
#  [ 10  38  65   8  39  58]]

# %%
tree = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.4440550903184347
# Accuracy:  0.4133138258961229
# F1 Score:  0.4044398761781985
# [[146  31   3  36  12   2]
#  [ 17 131  53   4  13   8]
#  [  4  63  82   1  13  46]
#  [112  38   6  65  11   5]
#  [ 17 113  24   9  59  25]
#  [  7  44  63   4  18  82]]

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)

# %%
tree = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.6002398010675669
# Accuracy:  0.5994152046783626
# F1 Score:  0.5926245355343905
# [[229 261]
#  [150 386]]

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)
# Out:
# Mounted at /content/drive

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.4, random_state=42)

# %%
tree = DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_leaf=2,
#                        min_samples_split=5)

# %%
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.3978278551527806
# Accuracy:  0.393562545720556
# F1 Score:  0.3938464582301009
# [[119  22  12  64  10   3]
#  [ 23  80  37  15  45  26]
#  [  9  57  71   4  18  50]
#  [ 79  16   6 115  15   6]
#  [ 20  64  40  20  80  23]
#  [  8  37  54   4  42  73]]

# %%
tree = DecisionTreeClassifier(criterion='gini', max_depth=9, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.44386333363992453
# Accuracy:  0.44111192392099485
# F1 Score:  0.44075336926488734
# [[124  15   7  63  19   2]
#  [ 22  92  46  14  31  21]
#  [ 10  47  81   1  16  54]
#  [ 58  10   8 133  18  10]
#  [ 20  61  25  19  86  36]
#  [ 11  36  57   7  20  87]]

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
tree = DecisionTreeClassifier(criterion='entropy', max_depth=30, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.6017599181284323
# Accuracy:  0.5994152046783626
# F1 Score:  0.5994323289719854
# [[307 183]
#  [228 308]]

# %%
tree = DecisionTreeClassifier(criterion='gini', max_depth=6, min_samples_split=5, min_samples_leaf=2)
tree.fit(X_train, y_train['label'].ravel())
y_pred = tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.6013570450883815
# Accuracy:  0.5994152046783626
# F1 Score:  0.5995190967969599
# [[304 186]
#  [225 311]]
