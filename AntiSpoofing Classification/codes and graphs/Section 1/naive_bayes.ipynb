# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
from google.colab import drive
drive.mount('/content/drive')
dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
"""print (dataset.shape)
dataset=dataset.sample(frac=1, replace=False)#shuffling dataset
print (dataset.shape)"""
labels=pd.DataFrame(dataset["label"])
dataset=dataset.drop("label",axis=1)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-b61b34fcf848> in <cell line: 6>()
#       4 from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, f1_score
#       5 from google.colab import drive
# ----> 6 drive.mount('/content/drive')
#       7 dataset=pd.read_csv("/content/drive/MyDrive/dataset.csv")
#       8 """print (dataset.shape)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
from sklearn.naive_bayes import GaussianNB
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
nb = GaussianNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.3576157380578147
# Accuracy:  0.3469785575048733
# F1 Score:  0.33610890410700983
# [[92 24  7 33  9  1]
#  [28 63 50  7 12  5]
#  [17 27 65  1 13 36]
#  [74 13  8 56 15  3]
#  [30 77 33  6 22 26]
#  [14 23 58  8 12 58]]

# %%
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)
nb = BernoulliNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.25932283218221946
# Accuracy:  0.2202729044834308
# F1 Score:  0.12152806433045447
# [[  0 163   0   0   0   3]
#  [  0 156   0   0   0   9]
#  [  0 155   1   0   0   3]
#  [  0 144   0   0   0  25]
#  [  0 149   0   0   0  45]
#  [  0 104   0   0   0  69]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
for index, row in labels.iterrows():
    if "fake" in row["label"]:
        row["label"]="fake"
    else :
        row["label"]="real"

# %%
for index, row in dataset.iterrows():
    row['fractional_dimension']=row['fractional_dimension']*10

X_train, X_test, y_train, y_test = train_test_split(dataset, labels, test_size=0.3, random_state=42)

# %%
nb = GaussianNB()
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.595628338611995
# Accuracy:  0.5818713450292398
# F1 Score:  0.5752971933692019
# [[352 138]
#  [291 245]]

# %%
nb = BernoulliNB(alpha=1.0, fit_prior=False)
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.7316835725213321
# Accuracy:  0.5984405458089669
# F1 Score:  0.5435969025474295
# [[475  15]
#  [397 139]]

# %%
df=dataset
print (dataset.keys)
# Out:
# <bound method NDFrame.keys of       brightness  contrast     pattern  color_difference  edge_density  \
# 0      99.702134  0.416570  175.309872         24.562875     88.403188
# 1      97.335692  0.623163  185.284147         57.123306     45.465668
# 2      92.069242  0.619442  177.027386         62.602832     72.193555
# 3     101.765685  0.612922  162.092529         63.141719     79.343781
# 4      89.973461  0.622225  162.502445         61.500500     31.618202
# ...          ...       ...         ...               ...           ...
# 3412  110.619807  0.399236  200.791773          3.726273     36.949285
# 3413  134.773247  0.375260  224.631836         22.195187     21.403370
# 3414  115.248466  0.412123  217.522831          4.510632     40.676422
# 3415  115.386924  0.413096  187.003233         19.096985     44.688034
# 3416  112.719294  0.354879  214.505047          4.233398     29.153035
#
#       fractional_dimension           b           g           r
# 0             5.364788e-01   59.150190  108.062914   98.769631
# 1             1.036944e+00   85.665575  103.026631   90.608499
# 2             9.941398e-01   88.460397   93.578682   90.488929
# 3             6.199279e-01   77.527173  108.002131   98.768269
# 4             9.604516e-01   58.748621   96.887482   88.296356
# ...                    ...         ...         ...         ...
# 3412          1.116414e-15  114.921968  112.496357  105.301193
# 3413          8.982784e-01  176.742966  137.606148  113.215843
# 3414          1.428571e-01  134.376606  124.196892   90.406948
# 3415          6.362820e-01  123.231947  117.173024  108.925603
# 3416          1.785714e-01  106.117772  111.112735  118.406194
#
# [3417 rows x 9 columns]>

# %%
from sklearn.naive_bayes import BernoulliNB,MultinomialNB
df=dataset
df=df.drop("edge_density",axis=1)
X_train, X_test, y_train, y_test = train_test_split(df, labels, test_size=0.3, random_state=42)
nb = BernoulliNB(alpha=1.0, fit_prior=False)
nb.fit(X_train, y_train['label'].ravel())
y_pred = nb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')

accuracy = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')

print("Precision: ", precision)
print("Accuracy: ", accuracy)
print("F1 Score: ", f1)
print (cm)
# Out:
# Precision:  0.7316835725213321
# Accuracy:  0.5984405458089669
# F1 Score:  0.5435969025474295
# [[475  15]
#  [397 139]]
