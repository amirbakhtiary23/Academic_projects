# %%
import matplotlib.pyplot as plt

# %%
labels=["SVM","BinarySVM","RF","7NN","en1","en2"]
accuracy=[0.84,0.82,0.98,0.96,0.97,0.98]
micro_avg_f1=[0.32,0.85,0.86,0.76,0.77,0.81]
micro_avg_recall=[0.22,0.60,0.75,0.63,0.66,0.63]
micro_avg_per=[0.24,0.62,0.79,0.64,0.68,0.66]
plt.bar(labels,accuracy)#),c="r")
plt.title("accuracy")
plt.show()

plt.bar(labels,micro_avg_f1)
plt.title("f1")
plt.show()

plt.bar(labels,micro_avg_recall)#,c="g")
plt.title("recall")
plt.show()

plt.bar(labels,micro_avg_per)#,c="y")
plt.title("precision")
plt.show()


plt.show()
